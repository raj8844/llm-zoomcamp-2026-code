# %%
import sys
print(sys.executable)
# Out:
# /workspaces/llm-zoomcamp-2026-code/.venv/bin/python

# %%
# %pip install google-genai
# Out:
# /workspaces/llm-zoomcamp-2026-code/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
import os

# %%
openai_client = OpenAI(
    api_key=os.getenv("GEMINI_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
uv add google
# Out:
# /workspaces/llm-zoomcamp-2026-code/.venv/bin/python: No module named uv
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
model_info = openai_client.models.get(model="gemini-3.5-flash")
print(model_info)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google import genai
#       2 model_info = openai_client.models.get(model="gemini-3.5-flash")
#       3 print(model_info)
#
# ModuleNotFoundError: No module named 'google'

# %%
response = openai_client.chat.completions.create(
    model="gemini-1.5-flash", # Or another compatible model
    messages=[
        {"role": "user", "content": "Hello Gemini!"}
    ]
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = openai_client.chat.completions.create(
#       2     model="gemini-1.5-flash", # Or another compatible model
#       3     messages=[
#       4         {"role": "user", "content": "Hello Gemini!"}
#
# File /workspaces/llm-zoomcamp-2026-code/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File /workspaces/llm-zoomcamp-2026-code/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File /workspaces/llm-zoomcamp-2026-code/.venv/lib/python3.12/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /workspaces/llm-zoomcamp-2026-code/.venv/lib/python3.12/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - [{'error': {'code': 404, 'message': 'models/gemini-1.5-flash is not found for API version v1main, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}]

# %%
def llm(prompt):
    response = openai_client.responses.create(
        model="gemini-1.5-flash",
        input=prompt
    )
    return response.output_text

# %%
llm("Hey, what's up?")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 llm("Hey, what's up?")
#
# Cell In[13], line 2, in llm(prompt)
#       1 def llm(prompt):
# ----> 2     response = openai_client.responses.create(
#       3         model="gemini-1.5-flash",
#       4         input=prompt
#       5     )
#
# File /workspaces/llm-zoomcamp-2026-code/.venv/lib/python3.12/site-packages/openai/resources/responses/responses.py:954, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     914 def create(
#     915     self,
#     916     *,
#    (...)    952     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     953 ) -> Response | Stream[ResponseStreamEvent]:
# --> 954     return self._post(
#     955         "/responses",
#     956         body=maybe_transform(
#     957             {
#     958                 "background": background,
#     959                 "context_management": context_management,
#     960                 "conversation": conversation,
#     961                 "include": include,
#     962                 "input": input,
#     963                 "instructions": instructions,
#     964                 "max_output_tokens": max_output_tokens,
#     965                 "max_tool_calls": max_tool_calls,
#     966                 "metadata": metadata,
#     967                 "model": model,
#     968                 "moderation": moderation,
#     969                 "parallel_tool_calls": parallel_tool_calls,
#     970                 "previous_response_id": previous_response_id,
#     971                 "prompt": prompt,
#     972                 "prompt_cache_key": prompt_cache_key,
#     973                 "prompt_cache_retention": prompt_cache_retention,
#     974                 "reasoning": reasoning,
#     975                 "safety_identifier": safety_identifier,
#     976                 "service_tier": service_tier,
#     977                 "store": store,
#     978                 "stream": stream,
#     979                 "stream_options": stream_options,
#     980                 "temperature": temperature,
#     981                 "text": text,
#     982                 "tool_choice": tool_choice,
#     983                 "tools": tools,
#     984                 "top_logprobs": top_logprobs,
#     985                 "top_p": top_p,
#     986                 "truncation": truncation,
#     987                 "user": user,
#     988             },
#     989             response_create_params.ResponseCreateParamsStreaming
#     990             if stream
#     991             else response_create_params.ResponseCreateParamsNonStreaming,
#     992         ),
#     993         options=make_request_options(
#     994             extra_headers=extra_headers,
#     995             extra_query=extra_query,
#     996             extra_body=extra_body,
#     997             timeout=timeout,
#     998             security={"bearer_auth": True},
#     999         ),
#    1000         cast_to=Response,
#    1001         stream=stream or False,
#    1002         stream_cls=Stream[ResponseStreamEvent],
#    1003     )
#
# File /workspaces/llm-zoomcamp-2026-code/.venv/lib/python3.12/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /workspaces/llm-zoomcamp-2026-code/.venv/lib/python3.12/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404
